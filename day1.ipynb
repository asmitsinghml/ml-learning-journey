# %% [markdown]
# # Today's Goal
# # Central tendency

# %%
data = [2, 4, 6, 8, 10]

# Mean
mean = sum(data) / len(data)

# Median
sorted_data = sorted(data)
n = len(sorted_data)

if n % 2 == 0:
    median = (sorted_data[n//2 - 1] + sorted_data[n//2]) / 2
else:
    median = sorted_data[n//2]

# Mode
freq = {}
for num in data:
    freq[num] = freq.get(num, 0) + 1

mode = max(freq, key=freq.get)

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 6.0
# Median: 6
# Mode: 2

# %%
# using statistics

# %%
import statistics

data = [2, 4, 6, 8, 10, 10]

print("Mean:", statistics.mean(data))
print("Median:", statistics.median(data))
print("Mode:", statistics.mode(data))
# Out:
# Mean: 6.666666666666667
# Median: 7.0
# Mode: 10

# %% [markdown]
# # using pandas

# %%
import pandas as pd

data = pd.Series([2, 4, 6, 8, 10, 10])

print("Mean:", data.mean())
print("Median:", data.median())
print("Mode:", data.mode()[0])
# Out:
# Mean: 6.666666666666667
# Median: 7.0
# Mode: 10

# %% [markdown]
# # using numpy

# %%
import numpy as np

data = np.array([2, 4, 6, 8, 10, 10])

print("Mean:", np.mean(data))
print("Median:", np.median(data))

# Mode (NumPy me direct nahi hota)
from scipy import stats
mode = stats.mode(data)

print("Mode:", mode.mode[0])
# Out:
# Mean: 6.666666666666667
# Median: 7.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 12
#       9 from scipy import stats
#      10 mode = stats.mode(data)
# ---> 12 print("Mode:", mode.mode[0])
#
# IndexError: invalid index to scalar variable.

# %%
# here is error due to there is nothing like mode in numpy

# %%
# !git add .
# !git commit -m "Day 1: Started ML journey"
# !git push
# Out:
# ...
# [main (root-commit) 66f80aa] Day 1: Started ML journey
#  3 files changed, 163 insertions(+)
#  create mode 100644 .ipynb_checkpoints/day1-checkpoint.ipynb
#  create mode 100644 anaconda_projects/db/project_filebrowser.db
#  create mode 100644 day1.ipynb
# To https://github.com/asmitsinghml/ml-learning-journey.git
#  * [new branch]      main -> main
